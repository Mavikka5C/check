# %% [markdown]
# <a href="https://colab.research.google.com/github/Mavikka5C/check/blob/main/Sapota.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/sales_data_1.csv")

# %%
df
# Out:
#         Date Firm bought from  Buying price   Customer  Selling price  \
# 0   21/08/23          Vendor6         72.11  Customer7          91.58
# 1   21/08/23          Vendor4         75.08  Customer7          83.71
# 2   21/08/23          Vendor7         83.93  Customer2         103.76
# 3   21/08/23          Vendor7         52.01  Customer3          64.53
# 4   21/08/23          Vendor2         98.91  Customer5         140.92
# ..       ...              ...           ...        ...            ...
# 65  27/08/23          Vendor4         64.82  Customer6          87.45
# 66  27/08/23          Vendor8         88.79  Customer3         105.59
# 67  27/08/23          Vendor5         63.30  Customer5          92.92
# 68  27/08/23          Vendor5         94.06  Customer5         125.67
# 69  27/08/23          Vendor5         56.28  Customer6          82.16
#
#     Quantity sold
# 0              44
# 1              17
# 2              15
# 3               7
# 4               1
# ...

# %%
df['Selling price'].sum()
# Out:
# 5173.93

# %%
df.dtypes
# Out:
# Date                 object
# Firm bought from     object
# Buying price        float64
# Customer             object
# Selling price       float64
# Quantity sold         int64
# dtype: object

# %%
df['profit']=(df['Selling price']-df['Buying price'])*df['Quantity sold']

# %%
df
# Out:
#         Date Firm bought from  Buying price   Customer  Selling price  \
# 0   21/08/23          Vendor6         72.11  Customer7          91.58
# 1   21/08/23          Vendor4         75.08  Customer7          83.71
# 2   21/08/23          Vendor7         83.93  Customer2         103.76
# 3   21/08/23          Vendor7         52.01  Customer3          64.53
# 4   21/08/23          Vendor2         98.91  Customer5         140.92
# ..       ...              ...           ...        ...            ...
# 65  27/08/23          Vendor4         64.82  Customer6          87.45
# 66  27/08/23          Vendor8         88.79  Customer3         105.59
# 67  27/08/23          Vendor5         63.30  Customer5          92.92
# 68  27/08/23          Vendor5         94.06  Customer5         125.67
# 69  27/08/23          Vendor5         56.28  Customer6          82.16
#
#     Quantity sold  profit
# 0              44  856.68
# 1              17  146.71
# 2              15  297.45
# ...

# %%
df['Firm bought from'].unique()
# Out:
# array(['Vendor6', 'Vendor4', 'Vendor7', 'Vendor2', 'Vendor9', 'Vendor3',
#        'Vendor1', 'Vendor5', 'Vendor10', 'Vendor8'], dtype=object)

# %%
df.groupby('Firm bought from')['profit'].sum()
# Out:
# Firm bought from
# Vendor1     1555.59
# Vendor10    3040.62
# Vendor2     1296.98
# Vendor3     6370.67
# Vendor4     6903.31
# Vendor5     1616.14
# Vendor6     1217.95
# Vendor7     4961.05
# Vendor8      253.74
# Vendor9     4266.70
# Name: profit, dtype: float64

# %%
df.groupby('Firm bought from')['profit'].sum().sum() #overall company's profit
# Out:
# 31482.75

# %%
df.groupby('Firm bought from')['profit'].sum().sort_values(ascending=False)
# Out:
# Firm bought from
# Vendor4     6903.31
# Vendor3     6370.67
# Vendor7     4961.05
# Vendor9     4266.70
# Vendor10    3040.62
# Vendor5     1616.14
# Vendor1     1555.59
# Vendor2     1296.98
# Vendor6     1217.95
# Vendor8      253.74
# Name: profit, dtype: float64

# %%
df.groupby('Firm bought from')['profit'].sum().sort_values(ascending=False).tail(1) #least profitable vendor
# Out:
# Firm bought from
# Vendor8    253.74
# Name: profit, dtype: float64

# %%
df.groupby('Firm bought from')['profit'].sum().sort_values(ascending=False).head(1) #most profitable vendor
# Out:
# Firm bought from
# Vendor4    6903.31
# Name: profit, dtype: float64

# %%
df['profit'].sum()  #overall company's profit
# Out:
# 31482.749999999996

# %%
(df['Selling price']*df['Quantity sold']).sum()
# Out:
# 127804.31

# %%
df['profit'].sum()*100/(df['Selling price']*df['Quantity sold']).sum()  #gross margin in %
# Out:
# 24.63355891518838

# %%
df.groupby('Customer')['profit'].sum()
# Out:
# Customer
# Customer1     5310.57
# Customer10    3692.44
# Customer2     4215.67
# Customer3     1055.05
# Customer4     3337.37
# Customer5     1315.28
# Customer6     1930.76
# Customer7     2197.62
# Customer8     6498.91
# Customer9     1929.08
# Name: profit, dtype: float64

# %%
df.groupby('Customer')['profit'].sum().sort_values(ascending=False).tail(1)  #least profitable customer
# Out:
# Customer
# Customer3    1055.05
# Name: profit, dtype: float64

# %%
df.groupby('Customer')['profit'].sum().sort_values(ascending=False).head(1)  #most profitable customer
# Out:
# Customer
# Customer8    6498.91
# Name: profit, dtype: float64

# %%
df.groupby('Date')['profit'].sum()
# Out:
# Date
# 21/08/23    6847.34
# 22/08/23    3305.35
# 23/08/23    4392.47
# 24/08/23    4866.03
# 25/08/23    3761.94
# 26/08/23    5223.16
# 27/08/23    3086.46
# Name: profit, dtype: float64

# %%
df.groupby('Date')['profit'].sum().sort_values(ascending=False).head(1) #day of the week was most profitable for them
# Out:
# Date
# 21/08/23    6847.34
# Name: profit, dtype: float64

# %%
df.groupby('Date')['profit'].sum().sort_values(ascending=False).tail(1) #day of the week was least profitable for them
# Out:
# Date
# 27/08/23    3086.46
# Name: profit, dtype: float64

# %%
d2=pd.read_csv("/content/sales_data_2.csv")

# %%
d2
# Out:
#           Date Firm bought from  Buying price  Quantity bought   Customer  \
# 0   2023-08-21          Vendor6         72.11               60  Customer7
# 1   2023-08-21          Vendor4         75.08               92  Customer7
# 2   2023-08-21          Vendor7         83.93               16  Customer2
# 3   2023-08-21          Vendor7         52.01               62  Customer3
# 4   2023-08-21          Vendor2         98.91                1  Customer5
# ..         ...              ...           ...              ...        ...
# 65  2023-08-27          Vendor4         64.82               28  Customer6
# 66  2023-08-27          Vendor8         88.79               14  Customer3
# 67  2023-08-27          Vendor5         63.30               81  Customer5
# 68  2023-08-27          Vendor5         94.06               18  Customer5
# 69  2023-08-27          Vendor5         56.28               25  Customer6
#
#     Selling price  Quantity sold
# 0           91.58             44
# ...

# %%
d2['profit']=(d2['Selling price']- d2['Buying price'])*d2['Quantity sold']

# %%
new=pd.DataFrame()

# %%
new['gm']=d2.groupby('Firm bought from')['profit'].sum()/(d2['Selling price']*d2['Quantity sold']).sum()*100

# %%
new['qs']=d2.groupby('Firm bought from')['Quantity sold'].sum()/d2.groupby('Firm bought from')['Quantity bought'].sum()*100

# %%
new
# Out:
#                         gm         qs
# Firm bought from
# Vendor1           1.217166  40.806045
# Vendor10          2.379122  53.846154
# Vendor2           1.014817  48.820755
# Vendor3           4.984707  65.242165
# Vendor4           5.401469  49.635036
# Vendor5           1.264543  29.721362
# Vendor6           0.952980  62.698413
# Vendor7           3.881755  42.925278
# Vendor8           0.198538  17.293233
# Vendor9           3.338463  60.931900

# %%
new.sort_values(by=['gm','qs'],ascending=False)
# Out:
#                         gm         qs
# Firm bought from
# Vendor4           5.401469  49.635036
# Vendor3           4.984707  65.242165
# Vendor7           3.881755  42.925278
# Vendor9           3.338463  60.931900
# Vendor10          2.379122  53.846154
# Vendor5           1.264543  29.721362
# Vendor1           1.217166  40.806045
# Vendor2           1.014817  48.820755
# Vendor6           0.952980  62.698413
# Vendor8           0.198538  17.293233

# %%
new.sort_values(by=['gm','qs'],ascending=False).head(1)
# Out:
#                         gm         qs
# Firm bought from
# Vendor4           5.401469  49.635036
